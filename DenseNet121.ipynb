# %% [markdown]
# <a href="https://colab.research.google.com/github/anasCSD/Glaucoma-Classification/blob/main/DenseNet121.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print("Pytorch version:", torch.__version__)
# Out:
# Pytorch version: 2.9.0+cu126

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# %pip install ipython-autotime
# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (75.2.0)
# Collecting jedi>=0.16 (from ipython->ipython-autotime)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.14)
# Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl (7.0 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.5 MB/s eta 0:00:00
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.2 jedi-0.19.2
# time: 231 µs (started: 2025-12-11 11:20:05 +00:00)

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# time: 9.48 s (started: 2025-12-11 11:20:06 +00:00)

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import numpy as np
import pathlib
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
import seaborn as sns
import os
import random
import shutil
import PIL as pil
import cv2
import matplotlib as mpl
import tqdm
from PIL import Image
from torchinfo import summary
from torchvision import datasets, transforms
from torch.utils.data import random_split, DataLoader
# Out:
# time: 3.54 ms (started: 2025-12-11 11:22:06 +00:00)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# time: 23.7 s (started: 2025-12-11 11:20:38 +00:00)

# %%
base_url = '/content/drive/MyDrive/Research'

batch_size = 4
img_height = 224
img_width = 224

class_names = ['glaucoma', 'normal']
# Out:
# time: 582 µs (started: 2025-12-11 11:21:04 +00:00)

# %%
def model_summary(model:torch.nn.Module,
                  input_size:tuple):
  return summary(model=model,
                input_size=input_size,
                col_names=["input_size", "output_size", "num_params", "trainable"],
                col_width=20,
                row_settings=['var_names'])
# Out:
# time: 635 µs (started: 2025-12-11 11:21:08 +00:00)

# %%
dataset_url = '/content/drive/MyDrive/Research/Glaucoma_Splitted'
train_path = f'{dataset_url}/train'
valid_path = f'{dataset_url}/val'
test_path  = f'{dataset_url}/test'
# Out:
# time: 979 µs (started: 2025-12-11 11:21:13 +00:00)

# %%
def apply_clahe(pil_img):
    img = np.array(pil_img)

    lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)

    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    cl = clahe.apply(l)

    lab = cv2.merge((cl, a, b))
    enhanced = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

    return Image.fromarray(enhanced)
# Out:
# time: 2.39 ms (started: 2025-12-11 11:22:11 +00:00)

# %%
train_transform = transforms.Compose([
    transforms.Lambda(lambda img: apply_clahe(img)),
    transforms.Resize((img_height, img_width)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=20),
    transforms.ColorJitter(brightness=0.1, contrast=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

val_test_transform = transforms.Compose([
    transforms.Lambda(lambda img: apply_clahe(img)),
    transforms.Resize((img_height, img_width)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# ==========================================================
#   DATASET & LOADERS
# ==========================================================
train_ds = datasets.ImageFolder(root=train_path, transform=train_transform)
valid_ds = datasets.ImageFolder(root=valid_path, transform=val_test_transform)
test_ds  = datasets.ImageFolder(root=test_path,  transform=val_test_transform)

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_ds, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False)
# Out:
# time: 6.25 s (started: 2025-12-11 11:22:18 +00:00)

# %%
num_classes = 2

model = torchvision.models.densenet121(weights='DEFAULT')

for param in model.parameters():
    param.requires_grad = False

model.classifier = nn.Sequential()

num_features = 1024

custom_classifier = nn.Sequential(
    nn.Linear(num_features, 1024),
    nn.ReLU(),
    nn.Linear(1024, 512),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(512, num_classes)
)

model.classifier = custom_classifier

model_summary(model=model,
              input_size=(4,3,224,224))
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 158MB/s]
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# DenseNet (DenseNet)                           [4, 3, 224, 224]     [4, 2]               --                   Partial
# ├─Sequential (features)                       [4, 3, 224, 224]     [4, 1024, 7, 7]      --                   False
# │    └─Conv2d (conv0)                         [4, 3, 224, 224]     [4, 64, 112, 112]    (9,408)              False
# │    └─BatchNorm2d (norm0)                    [4, 64, 112, 112]    [4, 64, 112, 112]    (128)                False
# │    └─ReLU (relu0)                           [4, 64, 112, 112]    [4, 64, 112, 112]    --                   --
# │    └─MaxPool2d (pool0)                      [4, 64, 112, 112]    [4, 64, 56, 56]      --                   --
# │    └─_DenseBlock (denseblock1)              [4, 64, 56, 56]      [4, 256, 56, 56]     --                   False
# │    │    └─_DenseLayer (denselayer1)         [4, 64, 56, 56]      [4, 32, 56, 56]      (45,440)             False
# │    │    └─_DenseLayer (denselayer2)         [4, 64, 56, 56]      [4, 32, 56, 56]      (49,600)             False
# │    │    └─_DenseLayer (denselayer3)         [4, 64, 56, 56]      [4, 32, 56, 56]      (53,760)             False
# │    │    └─_DenseLayer (denselayer4)         [4, 64, 56, 56]      [4, 32, 56, 56]      (57,920)             False
# │    │    └─_DenseLayer (denselayer5)         [4, 64, 56, 56]      [4, 32, 56, 56]      (62,080)             False
# │    │    └─_DenseLayer (denselayer6)         [4, 64, 56, 56]      [4, 32, 56, 56]      (66,240)             False
# │    └─_Transition (transition1)              [4, 256, 56, 56]     [4, 128, 28, 28]     --                   False
# │    │    └─BatchNorm2d (norm)                [4, 256, 56, 56]     [4, 256, 56, 56]     (512)                False
# │    │    └─ReLU (relu)                       [4, 256, 56, 56]     [4, 256, 56, 56]     --                   --
# │    │    └─Conv2d (conv)                     [4, 256, 56, 56]     [4, 128, 56, 56]     (32,768)             False
# │    │    └─AvgPool2d (pool)                  [4, 128, 56, 56]     [4, 128, 28, 28]     --                   --
# │    └─_DenseBlock (denseblock2)              [4, 128, 28, 28]     [4, 512, 28, 28]     --                   False
# │    │    └─_DenseLayer (denselayer1)         [4, 128, 28, 28]     [4, 32, 28, 28]      (53,760)             False
# │    │    └─_DenseLayer (denselayer2)         [4, 128, 28, 28]     [4, 32, 28, 28]      (57,920)             False
# │    │    └─_DenseLayer (denselayer3)         [4, 128, 28, 28]     [4, 32, 28, 28]      (62,080)             False
# │    │    └─_DenseLayer (denselayer4)         [4, 128, 28, 28]     [4, 32, 28, 28]      (66,240)             False
# │    │    └─_DenseLayer (denselayer5)         [4, 128, 28, 28]     [4, 32, 28, 28]      (70,400)             False
# │    │    └─_DenseLayer (denselayer6)         [4, 128, 28, 28]     [4, 32, 28, 28]      (74,560)             False
# │    │    └─_DenseLayer (denselayer7)         [4, 128, 28, 28]     [4, 32, 28, 28]      (78,720)             False
# │    │    └─_DenseLayer (denselayer8)         [4, 128, 28, 28]     [4, 32, 28, 28]      (82,880)             False
# │    │    └─_DenseLayer (denselayer9)         [4, 128, 28, 28]     [4, 32, 28, 28]      (87,040)             False
# │    │    └─_DenseLayer (denselayer10)        [4, 128, 28, 28]     [4, 32, 28, 28]      (91,200)             False
# │    │    └─_DenseLayer (denselayer11)        [4, 128, 28, 28]     [4, 32, 28, 28]      (95,360)             False
# │    │    └─_DenseLayer (denselayer12)        [4, 128, 28, 28]     [4, 32, 28, 28]      (99,520)             False
# │    └─_Transition (transition2)              [4, 512, 28, 28]     [4, 256, 14, 14]     --                   False
# │    │    └─BatchNorm2d (norm)                [4, 512, 28, 28]     [4, 512, 28, 28]     (1,024)              False
# │    │    └─ReLU (relu)                       [4, 512, 28, 28]     [4, 512, 28, 28]     --                   --
# │    │    └─Conv2d (conv)                     [4, 512, 28, 28]     [4, 256, 28, 28]     (131,072)            False
# │    │    └─AvgPool2d (pool)                  [4, 256, 28, 28]     [4, 256, 14, 14]     --                   --
# │    └─_DenseBlock (denseblock3)              [4, 256, 14, 14]     [4, 1024, 14, 14]    --                   False
# │    │    └─_DenseLayer (denselayer1)         [4, 256, 14, 14]     [4, 32, 14, 14]      (70,400)             False
# │    │    └─_DenseLayer (denselayer2)         [4, 256, 14, 14]     [4, 32, 14, 14]      (74,560)             False
# │    │    └─_DenseLayer (denselayer3)         [4, 256, 14, 14]     [4, 32, 14, 14]      (78,720)             False
# │    │    └─_DenseLayer (denselayer4)         [4, 256, 14, 14]     [4, 32, 14, 14]      (82,880)             False
# │    │    └─_DenseLayer (denselayer5)         [4, 256, 14, 14]     [4, 32, 14, 14]      (87,040)             False
# │    │    └─_DenseLayer (denselayer6)         [4, 256, 14, 14]     [4, 32, 14, 14]      (91,200)             False
# │    │    └─_DenseLayer (denselayer7)         [4, 256, 14, 14]     [4, 32, 14, 14]      (95,360)             False
# │    │    └─_DenseLayer (denselayer8)         [4, 256, 14, 14]     [4, 32, 14, 14]      (99,520)             False
# │    │    └─_DenseLayer (denselayer9)         [4, 256, 14, 14]     [4, 32, 14, 14]      (103,680)            False
# │    │    └─_DenseLayer (denselayer10)        [4, 256, 14, 14]     [4, 32, 14, 14]      (107,840)            False
# │    │    └─_DenseLayer (denselayer11)        [4, 256, 14, 14]     [4, 32, 14, 14]      (112,000)            False
# │    │    └─_DenseLayer (denselayer12)        [4, 256, 14, 14]     [4, 32, 14, 14]      (116,160)            False
# │    │    └─_DenseLayer (denselayer13)        [4, 256, 14, 14]     [4, 32, 14, 14]      (120,320)            False
# │    │    └─_DenseLayer (denselayer14)        [4, 256, 14, 14]     [4, 32, 14, 14]      (124,480)            False
# │    │    └─_DenseLayer (denselayer15)        [4, 256, 14, 14]     [4, 32, 14, 14]      (128,640)            False
# │    │    └─_DenseLayer (denselayer16)        [4, 256, 14, 14]     [4, 32, 14, 14]      (132,800)            False
# │    │    └─_DenseLayer (denselayer17)        [4, 256, 14, 14]     [4, 32, 14, 14]      (136,960)            False
# │    │    └─_DenseLayer (denselayer18)        [4, 256, 14, 14]     [4, 32, 14, 14]      (141,120)            False
# │    │    └─_DenseLayer (denselayer19)        [4, 256, 14, 14]     [4, 32, 14, 14]      (145,280)            False
# │    │    └─_DenseLayer (denselayer20)        [4, 256, 14, 14]     [4, 32, 14, 14]      (149,440)            False
# │    │    └─_DenseLayer (denselayer21)        [4, 256, 14, 14]     [4, 32, 14, 14]      (153,600)            False
# │    │    └─_DenseLayer (denselayer22)        [4, 256, 14, 14]     [4, 32, 14, 14]      (157,760)            False
# │    │    └─_DenseLayer (denselayer23)        [4, 256, 14, 14]     [4, 32, 14, 14]      (161,920)            False
# │    │    └─_DenseLayer (denselayer24)        [4, 256, 14, 14]     [4, 32, 14, 14]      (166,080)            False
# │    └─_Transition (transition3)              [4, 1024, 14, 14]    [4, 512, 7, 7]       --                   False
# │    │    └─BatchNorm2d (norm)                [4, 1024, 14, 14]    [4, 1024, 14, 14]    (2,048)              False
# │    │    └─ReLU (relu)                       [4, 1024, 14, 14]    [4, 1024, 14, 14]    --                   --
# │    │    └─Conv2d (conv)                     [4, 1024, 14, 14]    [4, 512, 14, 14]     (524,288)            False
# │    │    └─AvgPool2d (pool)                  [4, 512, 14, 14]     [4, 512, 7, 7]       --                   --
# │    └─_DenseBlock (denseblock4)              [4, 512, 7, 7]       [4, 1024, 7, 7]      --                   False
# │    │    └─_DenseLayer (denselayer1)         [4, 512, 7, 7]       [4, 32, 7, 7]        (103,680)            False
# │    │    └─_DenseLayer (denselayer2)         [4, 512, 7, 7]       [4, 32, 7, 7]        (107,840)            False
# │    │    └─_DenseLayer (denselayer3)         [4, 512, 7, 7]       [4, 32, 7, 7]        (112,000)            False
# │    │    └─_DenseLayer (denselayer4)         [4, 512, 7, 7]       [4, 32, 7, 7]        (116,160)            False
# │    │    └─_DenseLayer (denselayer5)         [4, 512, 7, 7]       [4, 32, 7, 7]        (120,320)            False
# │    │    └─_DenseLayer (denselayer6)         [4, 512, 7, 7]       [4, 32, 7, 7]        (124,480)            False
# │    │    └─_DenseLayer (denselayer7)         [4, 512, 7, 7]       [4, 32, 7, 7]        (128,640)            False
# │    │    └─_DenseLayer (denselayer8)         [4, 512, 7, 7]       [4, 32, 7, 7]        (132,800)            False
# │    │    └─_DenseLayer (denselayer9)         [4, 512, 7, 7]       [4, 32, 7, 7]        (136,960)            False
# │    │    └─_DenseLayer (denselayer10)        [4, 512, 7, 7]       [4, 32, 7, 7]        (141,120)            False
# │    │    └─_DenseLayer (denselayer11)        [4, 512, 7, 7]       [4, 32, 7, 7]        (145,280)            False
# │    │    └─_DenseLayer (denselayer12)        [4, 512, 7, 7]       [4, 32, 7, 7]        (149,440)            False
# │    │    └─_DenseLayer (denselayer13)        [4, 512, 7, 7]       [4, 32, 7, 7]        (153,600)            False
# │    │    └─_DenseLayer (denselayer14)        [4, 512, 7, 7]       [4, 32, 7, 7]        (157,760)            False
# │    │    └─_DenseLayer (denselayer15)        [4, 512, 7, 7]       [4, 32, 7, 7]        (161,920)            False
# │    │    └─_DenseLayer (denselayer16)        [4, 512, 7, 7]       [4, 32, 7, 7]        (166,080)            False
# │    └─BatchNorm2d (norm5)                    [4, 1024, 7, 7]      [4, 1024, 7, 7]      (2,048)              False
# ├─Sequential (classifier)                     [4, 1024]            [4, 2]               --                   True
# │    └─Linear (0)                             [4, 1024]            [4, 1024]            1,049,600            True
# │    └─ReLU (1)                               [4, 1024]            [4, 1024]            --                   --
# │    └─Linear (2)                             [4, 1024]            [4, 512]             524,800              True
# │    └─ReLU (3)                               [4, 512]             [4, 512]             --                   --
# │    └─Flatten (4)                            [4, 512]             [4, 512]             --                   --
# │    └─Linear (5)                             [4, 512]             [4, 2]               1,026                True
# =============================================================================================================================
# Total params: 8,529,282
# Trainable params: 1,575,426
# Non-trainable params: 6,953,856
# Total mult-adds (Units.GIGABYTES): 11.34
# =============================================================================================================================
# Input size (MB): 2.41
# Forward/backward pass size (MB): 722.18
# Params size (MB): 34.12
# Estimated Total Size (MB): 758.71
# =============================================================================================================================
# time: 1.68 s (started: 2025-12-11 11:22:38 +00:00)

# %%
params_to_train =  model.classifier.parameters()

model = model.to(device)

learning_rate = 0.00001
epochs = 50

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params_to_train, lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min')
# Out:
# time: 8.99 ms (started: 2025-12-11 11:22:50 +00:00)

# %%
filepath = f'{base_url}/Results/DenseNet121/model_preprocess.pth'
print(os.path.exists(filepath))
# Out:
# False
# time: 360 ms (started: 2025-12-11 11:23:02 +00:00)

# %%
def evaluate(model, data_loader, criterion):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    loss = running_loss / len(data_loader)
    accuracy = correct / total

    return loss, accuracy
# Out:
# time: 870 µs (started: 2025-12-11 11:23:48 +00:00)

# %%
def train(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs):

    # History lists to store curves
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    best_val_loss = float('inf')

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_loader)
        train_accuracy = correct / total

        # Validation check
        val_loss, val_accuracy = evaluate(model, val_loader, criterion)

        # Store in history
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)

        print(f"Epoch {epoch + 1}/{epochs}, "
              f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, "
              f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")

        scheduler.step(val_loss)

        # Save best model
        if val_loss < best_val_loss:
            torch.save(model.state_dict(), filepath)
            print(f"Model weights saved to {filepath}")
            best_val_loss = val_loss

    # Return history for plotting
    return train_losses, val_losses, train_accuracies, val_accuracies
# Out:
# time: 1.78 ms (started: 2025-12-11 11:23:51 +00:00)

# %%
train_losses, val_losses, train_acc, val_acc = train(
    model, train_loader, valid_loader, criterion, optimizer, scheduler, epochs
)
# Out:
# Epoch 1/50, Train Loss: 0.5292, Train Accuracy: 0.7784, Val Loss: 0.5140, Val Accuracy: 0.7775
# Model weights saved to /content/drive/MyDrive/Research/Results/DenseNet121/model_preprocess.pth
# Epoch 2/50, Train Loss: 0.5119, Train Accuracy: 0.7801, Val Loss: 0.5140, Val Accuracy: 0.7775
# Model weights saved to /content/drive/MyDrive/Research/Results/DenseNet121/model_preprocess.pth
# Epoch 3/50, Train Loss: 0.5106, Train Accuracy: 0.7801, Val Loss: 0.5087, Val Accuracy: 0.7775
# Model weights saved to /content/drive/MyDrive/Research/Results/DenseNet121/model_preprocess.pth
# Epoch 4/50, Train Loss: 0.5064, Train Accuracy: 0.7801, Val Loss: 0.5063, Val Accuracy: 0.7775
# Model weights saved to /content/drive/MyDrive/Research/Results/DenseNet121/model_preprocess.pth
# Epoch 5/50, Train Loss: 0.4980, Train Accuracy: 0.7801, Val Loss: 0.5000, Val Accuracy: 0.7775
# Model weights saved to /content/drive/MyDrive/Research/Results/DenseNet121/model_preprocess.pth
# Epoch 6/50, Train Loss: 0.5018, Train Accuracy: 0.7801, Val Loss: 0.4990, Val Accuracy: 0.7775
# Model weights saved to /content/drive/MyDrive/Research/Results/DenseNet121/model_preprocess.pth
# Epoch 7/50, Train Loss: 0.4930, Train Accuracy: 0.7801, Val Loss: 0.5226, Val Accuracy: 0.7775
# Epoch 8/50, Train Loss: 0.4915, Train Accuracy: 0.7807, Val Loss: 0.5052, Val Accuracy: 0.7775
# Epoch 9/50, Train Loss: 0.4879, Train Accuracy: 0.7818, Val Loss: 0.4938, Val Accuracy: 0.7775
# Model weights saved to /content/drive/MyDrive/Research/Results/DenseNet121/model_preprocess.pth
# Epoch 10/50, Train Loss: 0.4862, Train Accuracy: 0.7812, Val Loss: 0.4972, Val Accuracy: 0.7775
# Epoch 11/50, Train Loss: 0.4809, Train Accuracy: 0.7824, Val Loss: 0.5005, Val Accuracy: 0.7802
# Epoch 12/50, Train Loss: 0.4856, Train Accuracy: 0.7812, Val Loss: 0.5147, Val Accuracy: 0.7694
# Epoch 13/50, Train Loss: 0.4790, Train Accuracy: 0.7830, Val Loss: 0.5042, Val Accuracy: 0.7775
# Epoch 14/50, Train Loss: 0.4824, Train Accuracy: 0.7807, Val Loss: 0.4958, Val Accuracy: 0.7775
# Epoch 15/50, Train Loss: 0.4837, Train Accuracy: 0.7818, Val Loss: 0.4926, Val Accuracy: 0.7775
# Model weights saved to /content/drive/MyDrive/Research/Results/DenseNet121/model_preprocess.pth
# Epoch 16/50, Train Loss: 0.4774, Train Accuracy: 0.7841, Val Loss: 0.5052, Val Accuracy: 0.7721
# Epoch 17/50, Train Loss: 0.4664, Train Accuracy: 0.7818, Val Loss: 0.4961, Val Accuracy: 0.7748
# Epoch 18/50, Train Loss: 0.4742, Train Accuracy: 0.7841, Val Loss: 0.4942, Val Accuracy: 0.7748
# Epoch 19/50, Train Loss: 0.4686, Train Accuracy: 0.7789, Val Loss: 0.4987, Val Accuracy: 0.7748
# Epoch 20/50, Train Loss: 0.4760, Train Accuracy: 0.7824, Val Loss: 0.4995, Val Accuracy: 0.7775
# Epoch 21/50, Train Loss: 0.4640, Train Accuracy: 0.7870, Val Loss: 0.5092, Val Accuracy: 0.7802
# Epoch 22/50, Train Loss: 0.4686, Train Accuracy: 0.7882, Val Loss: 0.5164, Val Accuracy: 0.7641
# Epoch 23/50, Train Loss: 0.4713, Train Accuracy: 0.7818, Val Loss: 0.5006, Val Accuracy: 0.7748
# Epoch 24/50, Train Loss: 0.4711, Train Accuracy: 0.7818, Val Loss: 0.5006, Val Accuracy: 0.7802
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-556862321.py in <cell line: 0>()
# ----> 1 train_losses, val_losses, train_acc, val_acc = train(
#       2     model, train_loader, valid_loader, criterion, optimizer, scheduler, epochs
#       3 )
#
# /tmp/ipython-input-1427485611.py in train(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs)
#      15         total = 0
#      16
# ---> 17         for inputs, labels in train_loader:
#      18             inputs, labels = inputs.to(device), labels.to(device)
#      19             optimizer.zero_grad()
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     730                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731                 self._reset()  # type: ignore[call-arg]
# --> 732             data = self._next_data()
#     733             self._num_yielded += 1
#     734             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     786     def _next_data(self):
#     787         index = self._next_index()  # may raise StopIteration
# --> 788         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789         if self._pin_memory:
#     790             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     245         sample = self.loader(path)
#     246         if self.transform is not None:
# --> 247             sample = self.transform(sample)
#     248         if self.target_transform is not None:
#     249             target = self.target_transform(target)
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#     477
#     478     def __call__(self, img):
# --> 479         return self.lambd(img)
#     480
#     481     def __repr__(self) -> str:
#
# /tmp/ipython-input-1935752872.py in <lambda>(img)
#       1 train_transform = transforms.Compose([
# ----> 2     transforms.Lambda(lambda img: apply_clahe(img)),
#       3     transforms.Resize((img_height, img_width)),
#       4     transforms.RandomHorizontalFlip(p=0.5),
#       5     transforms.RandomRotation(degrees=20),
#
# /tmp/ipython-input-417235496.py in apply_clahe(pil_img)
#       9
#      10     lab = cv2.merge((cl, a, b))
# ---> 11     enhanced = cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)
#      12
#      13     return Image.fromarray(enhanced)
#
# KeyboardInterrupt:
# time: 3h 57min 10s (started: 2025-12-11 11:23:56 +00:00)

# %%
def plot_loss_curve(train_losses, val_losses):
    plt.figure(figsize=(10, 6))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training vs Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# time: 1.03 ms (started: 2025-12-11 15:21:14 +00:00)

# %%
def plot_accuracy_curve(train_acc, val_acc):
    plt.figure(figsize=(10, 6))
    plt.plot(train_acc, label='Train Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# time: 975 µs (started: 2025-12-11 15:21:17 +00:00)

# %%
plot_loss_curve(train_losses, val_losses)
plot_accuracy_curve(train_acc, val_acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1831111733.py in <cell line: 0>()
# ----> 1 plot_loss_curve(train_losses, val_losses)
#       2 plot_accuracy_curve(train_acc, val_acc)
#
# NameError: name 'train_losses' is not defined
# time: 10.5 ms (started: 2025-12-11 15:21:21 +00:00)

# %%
model.load_state_dict(torch.load(filepath))
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=2, bias=True)
#   )
# )
# time: 506 ms (started: 2025-11-24 20:02:31 +00:00)

# %%
test_loss, test_accuracy = evaluate(model, test_loader, criterion)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Loss: 0.4990, Test Accuracy: 0.7459
# time: 2min 19s (started: 2025-11-24 20:02:55 +00:00)

# %%
train_loss, train_accuracy = evaluate(model, train_loader, criterion)
print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")
# Out:
# Train Loss: 0.4056, Train Accuracy: 0.8096
# time: 2min 38s (started: 2025-11-24 20:05:36 +00:00)

# %%
val_loss, val_accuracy = evaluate(model, valid_loader, criterion)
print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Validation Loss: 0.4723, Validation Accuracy: 0.7641
# time: 40.2 s (started: 2025-11-24 20:08:35 +00:00)

# %%
def plot_confusion_matrix(model, dataloader, class_names, title="Confusion Matrix"):
    model.eval()
    all_actual = []
    all_predicted = []

    with torch.no_grad():
        for images, labels in dataloader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, preds = torch.max(outputs, 1)

            all_actual.extend(labels.cpu().numpy())
            all_predicted.extend(preds.cpu().numpy())

    all_actual = np.array(all_actual)
    all_predicted = np.array(all_predicted)

    cm = confusion_matrix(all_actual, all_predicted)
    print(f"\n{title}:\n", cm)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(title)
    plt.show()

    return cm
# Out:
# time: 1.09 ms (started: 2025-11-24 20:09:18 +00:00)

# %%
plot_confusion_matrix(model, train_loader, class_names, title="Training Confusion Matrix")
# Out:
# Training Confusion Matrix:
#  [[  97  283]
#  [  46 1302]]
# array([[  97,  283],
#        [  46, 1302]])
# time: 2min 40s (started: 2025-11-24 20:09:35 +00:00)

# %%
plot_confusion_matrix(model, valid_loader, class_names, title="Validation Confusion Matrix")
# Out:
# Validation Confusion Matrix:
#  [[ 10  73]
#  [ 15 275]]
# array([[ 10,  73],
#        [ 15, 275]])
# time: 37.8 s (started: 2025-11-24 20:13:00 +00:00)

# %%
plot_confusion_matrix(model, test_loader, class_names, title="Test Confusion Matrix")
# Out:
# Test Confusion Matrix:
#  [[  9  72]
#  [ 22 267]]
# array([[  9,  72],
#        [ 22, 267]])
# time: 34.1 s (started: 2025-11-24 20:13:47 +00:00)

# %%
def plot_roc_curve(model, test_loader, class_names):
    model.eval()
    y_true = []
    y_scores = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)

            probs = torch.softmax(outputs, dim=1)  # convert logits → probabilities

            y_true.extend(labels.cpu().numpy())
            y_scores.extend(probs.cpu().numpy())   # shape (batch,2)

    y_true = np.array(y_true)
    y_scores = np.array(y_scores)

    # ---- Manual 2-column binarize ----
    y_true_bin = np.zeros((len(y_true), len(class_names)))
    for idx, lab in enumerate(y_true):
        y_true_bin[idx, lab] = 1
    # ----------------------------------

    plt.figure(figsize=(10, 8))

    for i, name in enumerate(class_names):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        roc_auc = auc(fpr, tpr)

        print(f"Class {name} ROC AUC: {roc_auc:.3f}")
        plt.plot(fpr, tpr, label=f"{name} (AUC = {roc_auc:.3f})")

    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (DenseNet121)")
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()
# Out:
# time: 3.65 ms (started: 2025-11-24 20:15:08 +00:00)

# %%
plot_roc_curve(model, test_loader, class_names)
# Out:
# Class glaucoma ROC AUC: 0.672
# Class normal ROC AUC: 0.672
# time: 38.8 s (started: 2025-11-24 20:15:29 +00:00)

# %%
plot_roc_curve(model, valid_loader, class_names)
# Out:
# Class glaucoma ROC AUC: 0.714
# Class normal ROC AUC: 0.714
# time: 34.2 s (started: 2025-11-24 20:16:13 +00:00)

# %%
plot_roc_curve(model, train_loader, class_names)
# Out:
# Class glaucoma ROC AUC: 0.830
# Class normal ROC AUC: 0.830
# time: 2min 45s (started: 2025-11-24 20:16:52 +00:00)
